# %%
# !pip install twint
# Out:
# ...
#   Created wheel for twint: filename=twint-2.1.20-py3-none-any.whl size=33926 sha256=cc4f335dfa75c53a8c816017133c5c59ee755882a942cd7edb0bbc18c4a3c1c6
#   Stored in directory: c:\users\vedita kamat\appdata\local\pip\cache\wheels\44\fc\77\99887a36b5c265a87516158858697d1a0b8f32c4d4dbddbb24
# ...
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-py3-none-any.whl size=13489 sha256=dce53e099ba1444866a59f66cffb6c4b516ef27d76c3da6a34e38b6f00e4dda9
#   Stored in directory: c:\users\vedita kamat\appdata\local\pip\cache\wheels\ed\f7\62\50ab6c9a0b5567267ab76a9daa9d06315704209b2c5d032031
# ...
#   Created wheel for googletransx: filename=googletransx-2.4.2-py3-none-any.whl size=15975 sha256=f4a8eed84841e2593c5fa70755a74295f12066843b602e9b1666f3e107c4f7e1
#   Stored in directory: c:\users\vedita kamat\appdata\local\pip\cache\wheels\66\d5\b1\31104b338f7fd45aa8f7d22587765db06773b13df48a89735f
# Successfully built twint fake-useragent googletransx
# ...

# %%
# !pip install nest-asyncio

# %%
import twint
import nest_asyncio

# %%
nest_asyncio.apply()
c = twint.Config()
c.Search = "lockdown or covid" 
c.Since = "2020-03-23"
c.Until = "2020-04-18"
c.Pandas = True
c.Geo = "28.5934,77.2223,2000km"# Run
twint.run.Search(c)
# Out:
# 1251157393301368835 2020-04-17 20:05:42 India Standard Time <antonjawahar> A #Containment  operation (large outbreak or cluster) is deemed to be over 28 days from the date the last case  in the containment zone tests negative. #lockdown #Covid_19 #coronavirusinindia #Ministry_of_Health
# 1251145190116478978 2020-04-17 19:17:13 India Standard Time <Shobhit_R_S> @IndiGo6E I had a round trip from Pune to Lucknow, on 7th May to 13th May for 3 passengers. This trip won't be feasible as per current CoVID scenarios and lockdown. Could you please let me know the cancellation options? DM me for details like PNR or anything else.
# 1251141769636515840 2020-04-17 19:03:37 India Standard Time <FoodiesofIndia> Kesar sheera or kesari with rava, sugar, ghee and kesar paani! Ready in less then 20 mins 😋 Whats your favorite homemade dessert? #foodiesofindia #mumbai #lockdown #covid #cooking #indianfood #dessert @ Mumbai,…  https://www.instagram.com/p/B_FXQ7Kp9HP/?igshid=jr7jqblsgjnb …
# ...

# %%
df = twint.storage.panda.Tweets_df
df.head()
# Out:
#                     id      conversation_id     created_at  \
# 0  1251157393301368835  1251157393301368835  1587134142000
# 1  1251145190116478978  1251145190116478978  1587131233000
# 2  1251141769636515840  1251141769636515840  1587130417000
# 3  1251134828637908993  1251134828637908993  1587128762000
# 4  1251084399585529857  1251084399585529857  1587116739000
#
#                   date             timezone place  \
# 0  2020-04-17 20:05:42  India Standard Time
# 1  2020-04-17 19:17:13  India Standard Time
# 2  2020-04-17 19:03:37  India Standard Time
# 3  2020-04-17 18:36:02  India Standard Time
# 4  2020-04-17 15:15:39  India Standard Time
#
#                                                tweet  \
# 0  A #Containment \noperation (large outbreak or ...
# 1  @IndiGo6E I had a round trip from Pune to Luck...
# 2  Kesar sheera or kesari with rava, sugar, ghee ...
# 3  STUPID Fucking woman, Ingraham, we didn't lock...
# 4  Due to COVID-19 Lockdown it's become difficult...
#
# ...

# %%
df.columns

# %%
df=df[['id','conversation_id', 'created_at', 'date','tweet', 'hashtags',]]

# %%
df

# %%
df.to_csv('Lockdown1.0.csv')

# %%
import pandas as pd

# %%
data = pd.read_csv('Lockdown1.0.csv',encoding='latin1')

# %%
data
# Out:
#      Unnamed: 0            id  conversation_id    created_at        date  \
# 0             0  1.250000e+18     1.250000e+18  1.590000e+12  17-04-2020
# 1             1  1.250000e+18     1.250000e+18  1.590000e+12  17-04-2020
# 2             2  1.250000e+18     1.250000e+18  1.590000e+12  17-04-2020
# 3             3  1.250000e+18     1.250000e+18  1.590000e+12  17-04-2020
# 4             4  1.250000e+18     1.250000e+18  1.590000e+12  17-04-2020
# ..          ...           ...              ...           ...         ...
# 306         306  1.240000e+18     1.240000e+18  1.580000e+12  23-03-2020
# 307         307  1.240000e+18     1.240000e+18  1.580000e+12  23-03-2020
# 308         308  1.240000e+18     1.240000e+18  1.580000e+12  23-03-2020
# 309         309  1.240000e+18     1.240000e+18  1.580000e+12  23-03-2020
# 310         310  1.240000e+18     1.240000e+18  1.580000e+12  23-03-2020
#
#                                                  tweet  \
# ...
