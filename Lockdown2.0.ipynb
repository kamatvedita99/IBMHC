# %%
import twint
import nest_asyncio

# %%
nest_asyncio.apply()
c = twint.Config()
c.Search = "lockdown" 
c.Since = "2020-04-19"
c.Until = "2020-05-04"
c.Pandas = True
c.Geo = "28.5934,77.2223,2000km"# Run
twint.run.Search(c)
# Out:
# 1257014450638520320 2020-05-03 23:59:33 +0530 <dhananjayD_21> BOI Pune minimum bal charges debited in lockdown @AjitPawarSpeaks pic.twitter.com/F2APAXXTgh – at Pune, Maharashtra
# 1257014275698237450 2020-05-03 23:58:52 +0530 <shreya2107> मैं सरकार से प्रार्थना करती हूँ कि आप इनकी मदद करें। India please take a stand for these warriors too. #coronavirus #lockdown @anjanaomkashyap @aajtak @punjabkesari @BJP4India @ChouhanShivraj @myogiadityanath @narendramodi  https://twitter.com/iSinghDeepika/status/1256925663010992128 … pic.twitter.com/Y6w8wj4Czo
# 1257014081443201024 2020-05-03 23:58:05 +0530 <sunnybhagt> So today one of my special day is completely ruined because of this lockdown and scary corona virus. thank you all for giving me so much love today. #china_kmkb
# ...

# %%
df = twint.storage.panda.Tweets_df
df
# Out:
#                       id      conversation_id     created_at  \
# 0    1257006813846949888  1257006813846949888  1588528753000
# 1    1256960918874980352  1256960918874980352  1588517810000
# 2    1256944300052688896  1256944300052688896  1588513848000
# 3    1256927438547935232  1256927438547935232  1588509828000
# 4    1256916856713162752  1256916856713162752  1588507305000
# ..                   ...                  ...            ...
# 152  1251777711674142720  1251777711674142720  1587282038000
# 153  1251763210748715009  1251482048352542721  1587278580000
# 154  1251747912222150658  1251493027035533312  1587274933000
# 155  1251741716568104962  1251741716568104962  1587273456000
# 156  1251712671214383105  1251711222178811904  1587266531000
#
#                     date timezone place  \
# 0    2020-05-03 23:29:13    +0530
# 1    2020-05-03 20:26:50    +0530
# 2    2020-05-03 19:20:48    +0530
# 3    2020-05-03 18:13:48    +0530
# 4    2020-05-03 17:31:45    +0530
# ...

# %%
df=df[['id','conversation_id', 'created_at', 'date','tweet', 'hashtags',]]

# %%
df.to_csv('Lockdown2.0.csv')
